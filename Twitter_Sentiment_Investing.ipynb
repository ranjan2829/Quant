# %% [markdown]
# <a href="https://colab.research.google.com/github/ranjan2829/Quant/blob/main/Twitter_Sentiment_Investing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import yfinance as yf
import os

# %%
plt.style.use('ggplot')
sentiment=pd.read_csv('sentiment_data.csv')

# %%
sentiment['date']=pd.to_datetime(sentiment['date'])
sentiment
# Out:
#             date symbol  twitterPosts  twitterComments  twitterLikes  \
# 0     2021-11-18   AAPL         811.0           2592.0       21674.0
# 1     2021-11-18    ABT          21.0              3.0          13.0
# 2     2021-11-18    AMD         150.0            675.0        2949.0
# 3     2021-11-18   AMZN         557.0           1315.0       12969.0
# 4     2021-11-18   ATVI          82.0             36.0         131.0
# ...          ...    ...           ...              ...           ...
# 27230 2023-01-04    TMO          21.0              2.0          32.0
# 27231 2023-01-04   TSLA        6767.0         540711.0     3810688.0
# 27232 2023-01-04    TSN          35.0            168.0         460.0
# 27233 2023-01-04      V         132.0           1008.0        5943.0
# 27234 2023-01-04    XOM         212.0            374.0        2071.0
#
#        twitterImpressions  twitterSentiment
# 0               7981808.0               NaN
# 1                 64089.0               NaN
# ...

# %%
sentiment=sentiment.set_index(['date','symbol'])

# %%
sentiment
# Out:
#                    twitterPosts  twitterComments  twitterLikes  \
# date       symbol
# 2021-11-18 AAPL           811.0           2592.0       21674.0
#            ABT             21.0              3.0          13.0
#            AMD            150.0            675.0        2949.0
#            AMZN           557.0           1315.0       12969.0
#            ATVI            82.0             36.0         131.0
# ...                         ...              ...           ...
# 2023-01-04 TMO             21.0              2.0          32.0
#            TSLA          6767.0         540711.0     3810688.0
#            TSN             35.0            168.0         460.0
#            V              132.0           1008.0        5943.0
#            XOM            212.0            374.0        2071.0
#
#                    twitterImpressions  twitterSentiment
# date       symbol
# 2021-11-18 AAPL             7981808.0               NaN
#            ABT                64089.0               NaN
# ...

# %%
sentiment['engagement_ratio']=sentiment['twitterComments']/sentiment['twitterLikes']
sentiment=sentiment[(sentiment['twitterLikes']>20)&(sentiment['twitterComments']>10)]

# %%
sentiment
# Out:
#                    twitterPosts  twitterComments  twitterLikes  \
# date       symbol
# 2021-11-18 AAPL           811.0           2592.0       21674.0
#            AMD            150.0            675.0        2949.0
#            AMZN           557.0           1315.0       12969.0
#            ATVI            82.0             36.0         131.0
#            BA              61.0             55.0         342.0
# ...                         ...              ...           ...
# 2023-01-04 T              184.0           3409.0       14271.0
#            TSLA          6767.0         540711.0     3810688.0
#            TSN             35.0            168.0         460.0
#            V              132.0           1008.0        5943.0
#            XOM            212.0            374.0        2071.0
#
#                    twitterImpressions  twitterSentiment  engagement_ratio
# date       symbol
# 2021-11-18 AAPL             7981808.0               NaN          0.119590
# ...

# %%
aggragate=(sentiment.reset_index('symbol').groupby([pd.Grouper(freq='M'),'symbol'])
           [['engagement_ratio']].mean())

# %%
aggragate['rank']=(aggragate.groupby(level=0)['engagement_ratio']
                   .transform(lambda x: x.rank(ascending=False)))

# %%
aggragate
# Out:
#                    engagement_ratio  rank
# date       symbol
# 2021-11-30 AAL             0.203835  37.0
#            AAPL            0.256318  23.0
#            ABBV            0.244677  26.0
#            ABT             0.313368  14.0
#            AES             0.864613   2.0
# ...                             ...   ...
# 2023-01-31 TMO             0.333313  19.0
#            TSLA            0.151992  72.0
#            TSN             0.280553  30.0
#            V               0.194045  60.0
#            XOM             0.217904  53.0
#
# [1109 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# aggragate['engagement_ratio'].plot(kind='hist', bins=20, title='engagement_ratio')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
filter =aggragate[aggragate['rank']<6].copy()
filter=filter.reset_index(level=1)
filter.index=filter.index+pd.DateOffset(1)
filter=filter.reset_index().set_index(['date','symbol'])
filter.head(20)
# Out:
#                    engagement_ratio  rank
# date       symbol
# 2021-12-01 AES             0.864613   2.0
#            FCX             0.626323   5.0
#            MNST            0.699721   3.0
#            OXY             2.147741   1.0
#            SLB             0.647374   4.0
# 2022-01-01 D               0.801994   5.0
#            FCX             0.841220   4.0
#            L               6.507246   1.0
#            LUV             1.303215   2.0
#            MA              0.883401   3.0
# 2022-02-01 AMD             0.715556   4.0
#            D               1.136678   1.0
#            FCX             0.655237   5.0
#            LUV             1.035258   2.0
#            MA              0.729063   3.0
# 2022-03-01 FCX             1.138332   2.0
#            GILD            0.530886   5.0
#            LUV             1.574377   1.0
#            MRO             0.581748   4.0
#            OXY             1.025579   3.0

# %%
dates=filter.index.get_level_values('date').unique().tolist()
fixed={}
for d in dates:
  fixed[d.strftime('%Y-%m-%d')]=filter.xs(d,level=0).index.tolist()
fixed
# Out:
# {'2021-12-01': ['AES', 'FCX', 'MNST', 'OXY', 'SLB'],
#  '2022-01-01': ['D', 'FCX', 'L', 'LUV', 'MA'],
#  '2022-02-01': ['AMD', 'D', 'FCX', 'LUV', 'MA'],
#  '2022-03-01': ['FCX', 'GILD', 'LUV', 'MRO', 'OXY'],
#  '2022-04-01': ['A', 'CRM', 'PFE', 'PM', 'STZ'],
#  '2022-05-01': ['AMD', 'CRM', 'CVX', 'J', 'KEY'],
#  '2022-06-01': ['AMD', 'DD', 'FCX', 'KEY', 'LMT'],
#  '2022-07-01': ['CB', 'CRM', 'DD', 'FCX', 'STZ'],
#  '2022-08-01': ['A', 'DD', 'JPM', 'REGN', 'STZ'],
#  '2022-09-01': ['ABT', 'DIS', 'L', 'META', 'MRNA'],
#  '2022-10-01': ['J', 'KEY', 'L', 'META', 'MU'],
#  '2022-11-01': ['A', 'DD', 'FCX', 'J', 'META'],
#  '2022-12-01': ['AEP', 'AES', 'DD', 'J', 'STZ'],
#  '2023-01-01': ['A', 'AES', 'DAL', 'J', 'KEY'],
#  '2023-02-01': ['A', 'AES', 'BIIB', 'FCX', 'MDT']}

# %%
stocks_list = sentiment.index.get_level_values('symbol').unique().tolist()

# Remove the problematic stock 'ATVI' from the list
stocks_list.remove('ATVI')

# Download prices for the remaining stocks
prices_data = yf.download(tickers=stocks_list,
                          start='2021-01-01',
                          end='2023-03-01')
# Out:
# [*********************100%%**********************]  84 of 84 completed

# %%
import numpy as np
import pandas as pd

# Assuming you already have prices_df and fixed defined

returns_df = np.log(prices_df['Adj Close']).diff().dropna()

portfolio_df = pd.DataFrame()

for start_date in fixed.keys():
    end_date = (pd.to_datetime(start_date) + pd.offsets.MonthEnd()).strftime('%Y-%m-%d')
    cols = fixed[start_date]

    # Print for debugging
    print(f"Processing date range: {start_date} to {end_date}")
    print(f"Selected columns: {cols}")

    selected_data = returns_df[start_date:end_date][cols]

    # Check for NaN values in the selected data
    if selected_data.isnull().values.any():
        print("Warning: NaN values found in the selected data. Check for missing or incomplete data.")

    temp_df = selected_data.mean(axis=1).to_frame('portfolio_return')

    # Print intermediate results
    print(f"Portfolio returns for date range {start_date} to {end_date}:")
    print(temp_df)

    portfolio_df = pd.concat([portfolio_df, temp_df], axis=0)

# Print final result
print("Final portfolio returns:")
print(portfolio_df)
# Out:
# Processing date range: 2021-12-01 to 2021-12-31
# Selected columns: ['AES', 'FCX', 'MNST', 'OXY', 'SLB']
# Portfolio returns for date range 2021-12-01 to 2021-12-31:
# Empty DataFrame
# Columns: [portfolio_return]
# Index: []
# Processing date range: 2022-01-01 to 2022-01-31
# Selected columns: ['D', 'FCX', 'L', 'LUV', 'MA']
# Portfolio returns for date range 2022-01-01 to 2022-01-31:
# Empty DataFrame
# Columns: [portfolio_return]
# Index: []
# Processing date range: 2022-02-01 to 2022-02-28
# Selected columns: ['AMD', 'D', 'FCX', 'LUV', 'MA']
# Portfolio returns for date range 2022-02-01 to 2022-02-28:
# Empty DataFrame
# Columns: [portfolio_return]
# Index: []
# Processing date range: 2022-03-01 to 2022-03-31
# Selected columns: ['FCX', 'GILD', 'LUV', 'MRO', 'OXY']
# Portfolio returns for date range 2022-03-01 to 2022-03-31:
# Empty DataFrame
# Columns: [portfolio_return]
# Index: []
# Processing date range: 2022-04-01 to 2022-04-30
# ...

# %%
portfolio_df
# Out:
# Empty DataFrame
# Columns: [portfolio_return]
# Index: []

# %%
import pandas as pd

# Assuming you have the data you provided in a DataFrame named 'data'
# Replace 'data' with the actual name of your DataFrame

# Sample data
data = {
    'Date': ['2021-12-01', '2021-12-02', '2021-12-03', '2021-12-06', '2021-12-07'],
    'portfolio_return': [-0.016417, 0.024872, -0.007711, 0.023926, 0.030547],
    'nasdaq_return': [-0.017159, 0.007181, -0.017542, 0.007981, 0.029669]
}

data['Date'] = pd.to_datetime(data['Date'])
data = pd.DataFrame(data).set_index('Date')

# Assuming you have a fixed dictionary similar to this
fixed = {
    '2021-12-01': ['portfolio_return', 'nasdaq_return'],
    '2021-12-02': ['portfolio_return', 'nasdaq_return'],
    '2021-12-03': ['portfolio_return', 'nasdaq_return'],
    '2021-12-06': ['portfolio_return', 'nasdaq_return'],
    '2021-12-07': ['portfolio_return', 'nasdaq_return']
}

portfolio_df = pd.DataFrame()

for start_date in fixed.keys():
    end_date = (pd.to_datetime(start_date) + pd.offsets.MonthEnd()).strftime('%Y-%m-%d')
    cols = fixed[start_date]

    temp_df = data[start_date:end_date][cols].mean(axis=1).to_frame('portfolio_return')
    portfolio_df = pd.concat([portfolio_df, temp_df], axis=0)

print(portfolio_df)
# Out:
#             portfolio_return
# Date
# 2021-12-01         -0.016788
# 2021-12-02          0.016026
# 2021-12-03         -0.012626
# 2021-12-06          0.015953
# 2021-12-07          0.030108
# 2021-12-02          0.016026
# 2021-12-03         -0.012626
# 2021-12-06          0.015953
# 2021-12-07          0.030108
# 2021-12-03         -0.012626
# 2021-12-06          0.015953
# 2021-12-07          0.030108
# 2021-12-06          0.015953
# 2021-12-07          0.030108
# 2021-12-07          0.030108

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# Assuming you already have portfolios_cumulative_return defined
# If not, you can calculate it as follows:
# portfolios_cumulative_return = np.exp(np.log1p(portfolio_df).cumsum()).sub(1)

# Check for NaN values and drop them
portfolios_cumulative_return = portfolios_cumulative_return.dropna()

# Check if the DataFrame is empty
if portfolios_cumulative_return.empty:
    print("Error: Empty DataFrame. Check your data.")

# Plotting code
plt.figure(figsize=(16, 6))
plt.plot(portfolios_cumulative_return, label='Cumulative Return')

plt.title('Twitter Engagement Ratio Strategy Cumulative Returns Over Time')
plt.ylabel('Cumulative Return')
plt.legend()

# Use PercentFormatter to format y-axis as percentages
plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(1))

plt.show()
# Out:
# Error: Empty DataFrame. Check your data.
